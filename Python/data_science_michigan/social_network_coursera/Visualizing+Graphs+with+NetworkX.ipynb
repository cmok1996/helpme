# %% [markdown]
# # Visualizing Networks

# %%
# %matplotlib notebook

import networkx as nx
import matplotlib.pyplot as plt

# read in the graph 
G = nx.read_gpickle('major_us_cities')
G.edges()
# Out:
# [('El Paso, TX', 'Albuquerque, NM'),
#  ('El Paso, TX', 'Mesa, AZ'),
#  ('El Paso, TX', 'Tucson, AZ'),
#  ('El Paso, TX', 'Phoenix, AZ'),
#  ('El Paso, TX', 'Colorado Springs, CO'),
#  ('Long Beach, CA', 'Oakland, CA'),
#  ('Long Beach, CA', 'Mesa, AZ'),
#  ('Long Beach, CA', 'Sacramento, CA'),
#  ('Long Beach, CA', 'Tucson, AZ'),
#  ('Long Beach, CA', 'San Jose, CA'),
#  ('Long Beach, CA', 'Fresno, CA'),
#  ('Long Beach, CA', 'San Diego, CA'),
#  ('Long Beach, CA', 'Phoenix, AZ'),
#  ('Long Beach, CA', 'San Francisco, CA'),
#  ('Long Beach, CA', 'Los Angeles, CA'),
#  ('Long Beach, CA', 'Las Vegas, NV'),
#  ('Dallas, TX', 'Arlington, TX'),
#  ('Dallas, TX', 'Wichita, KS'),
#  ('Dallas, TX', 'Oklahoma City, OK'),
#  ('Dallas, TX', 'New Orleans, LA'),
#  ('Dallas, TX', 'Houston, TX'),
#  ('Dallas, TX', 'Kansas City, MO'),
#  ('Dallas, TX', 'San Antonio, TX'),
#  ('Dallas, TX', 'Memphis, TN'),
#  ('Dallas, TX', 'Tulsa, OK'),
#  ('Dallas, TX', 'Austin, TX'),
#  ('Dallas, TX', 'Fort Worth, TX'),
#  ('Oakland, CA', 'Sacramento, CA'),
#  ('Oakland, CA', 'San Jose, CA'),
#  ('Oakland, CA', 'Fresno, CA'),
#  ('Oakland, CA', 'San Diego, CA'),
#  ('Oakland, CA', 'San Francisco, CA'),
#  ('Oakland, CA', 'Los Angeles, CA'),
#  ('Oakland, CA', 'Las Vegas, NV'),
#  ('Albuquerque, NM', 'Mesa, AZ'),
#  ('Albuquerque, NM', 'Tucson, AZ'),
#  ('Albuquerque, NM', 'Phoenix, AZ'),
#  ('Albuquerque, NM', 'Denver, CO'),
#  ('Albuquerque, NM', 'Colorado Springs, CO'),
#  ('Albuquerque, NM', 'Las Vegas, NV'),
#  ('Baltimore, MD', 'Raleigh, NC'),
#  ('Baltimore, MD', 'Cleveland, OH'),
#  ('Baltimore, MD', 'Philadelphia, PA'),
#  ('Baltimore, MD', 'Boston, MA'),
#  ('Baltimore, MD', 'Charlotte, NC'),
#  ('Baltimore, MD', 'Washington D.C.'),
#  ('Baltimore, MD', 'New York, NY'),
#  ('Baltimore, MD', 'Detroit, MI'),
#  ('Baltimore, MD', 'Columbus, OH'),
#  ('Baltimore, MD', 'Virginia Beach, VA'),
#  ('Raleigh, NC', 'Cleveland, OH'),
#  ('Raleigh, NC', 'Louisville/Jefferson County, KY'),
#  ('Raleigh, NC', 'Atlanta, GA'),
#  ('Raleigh, NC', 'Philadelphia, PA'),
#  ('Raleigh, NC', 'Charlotte, NC'),
#  ('Raleigh, NC', 'Washington D.C.'),
#  ('Raleigh, NC', 'New York, NY'),
#  ('Raleigh, NC', 'Indianapolis, IN'),
#  ('Raleigh, NC', 'Nashville-Davidson, TN'),
#  ('Raleigh, NC', 'Columbus, OH'),
#  ('Raleigh, NC', 'Virginia Beach, VA'),
#  ('Raleigh, NC', 'Jacksonville, FL'),
#  ('Mesa, AZ', 'Tucson, AZ'),
#  ('Mesa, AZ', 'San Diego, CA'),
#  ('Mesa, AZ', 'Phoenix, AZ'),
#  ('Mesa, AZ', 'Los Angeles, CA'),
#  ('Mesa, AZ', 'Las Vegas, NV'),
#  ('Arlington, TX', 'Wichita, KS'),
#  ('Arlington, TX', 'Oklahoma City, OK'),
#  ('Arlington, TX', 'New Orleans, LA'),
#  ('Arlington, TX', 'Houston, TX'),
#  ('Arlington, TX', 'Kansas City, MO'),
#  ('Arlington, TX', 'San Antonio, TX'),
#  ('Arlington, TX', 'Memphis, TN'),
#  ('Arlington, TX', 'Tulsa, OK'),
#  ('Arlington, TX', 'Austin, TX'),
#  ('Arlington, TX', 'Fort Worth, TX'),
#  ('Sacramento, CA', 'San Jose, CA'),
#  ('Sacramento, CA', 'Fresno, CA'),
#  ('Sacramento, CA', 'San Diego, CA'),
#  ('Sacramento, CA', 'San Francisco, CA'),
#  ('Sacramento, CA', 'Los Angeles, CA'),
#  ('Sacramento, CA', 'Portland, OR'),
#  ('Sacramento, CA', 'Las Vegas, NV'),
#  ('Wichita, KS', 'Oklahoma City, OK'),
#  ('Wichita, KS', 'Kansas City, MO'),
#  ('Wichita, KS', 'Memphis, TN'),
#  ('Wichita, KS', 'Denver, CO'),
#  ('Wichita, KS', 'Omaha, NE'),
#  ('Wichita, KS', 'Tulsa, OK'),
#  ('Wichita, KS', 'Colorado Springs, CO'),
#  ('Wichita, KS', 'Fort Worth, TX'),
#  ('Tucson, AZ', 'San Diego, CA'),
#  ('Tucson, AZ', 'Phoenix, AZ'),
#  ('Tucson, AZ', 'Los Angeles, CA'),
#  ('Tucson, AZ', 'Las Vegas, NV'),
#  ('Cleveland, OH', 'Louisville/Jefferson County, KY'),
#  ('Cleveland, OH', 'Philadelphia, PA'),
#  ('Cleveland, OH', 'Chicago, IL'),
#  ('Cleveland, OH', 'Charlotte, NC'),
#  ('Cleveland, OH', 'Washington D.C.'),
#  ('Cleveland, OH', 'New York, NY'),
#  ('Cleveland, OH', 'Indianapolis, IN'),
#  ('Cleveland, OH', 'Detroit, MI'),
#  ('Cleveland, OH', 'Nashville-Davidson, TN'),
#  ('Cleveland, OH', 'Milwaukee, WI'),
#  ('Cleveland, OH', 'Columbus, OH'),
#  ('Cleveland, OH', 'Virginia Beach, VA'),
#  ('Louisville/Jefferson County, KY', 'Atlanta, GA'),
#  ('Louisville/Jefferson County, KY', 'Kansas City, MO'),
#  ('Louisville/Jefferson County, KY', 'Chicago, IL'),
#  ('Louisville/Jefferson County, KY', 'Charlotte, NC'),
#  ('Louisville/Jefferson County, KY', 'Washington D.C.'),
#  ('Louisville/Jefferson County, KY', 'Memphis, TN'),
#  ('Louisville/Jefferson County, KY', 'Indianapolis, IN'),
#  ('Louisville/Jefferson County, KY', 'Detroit, MI'),
#  ('Louisville/Jefferson County, KY', 'Nashville-Davidson, TN'),
#  ('Louisville/Jefferson County, KY', 'Milwaukee, WI'),
#  ('Louisville/Jefferson County, KY', 'Columbus, OH'),
#  ('San Jose, CA', 'Fresno, CA'),
#  ('San Jose, CA', 'San Diego, CA'),
#  ('San Jose, CA', 'San Francisco, CA'),
#  ('San Jose, CA', 'Los Angeles, CA'),
#  ('San Jose, CA', 'Las Vegas, NV'),
#  ('Oklahoma City, OK', 'Houston, TX'),
#  ('Oklahoma City, OK', 'Kansas City, MO'),
#  ('Oklahoma City, OK', 'San Antonio, TX'),
#  ('Oklahoma City, OK', 'Memphis, TN'),
#  ('Oklahoma City, OK', 'Omaha, NE'),
#  ('Oklahoma City, OK', 'Tulsa, OK'),
#  ('Oklahoma City, OK', 'Austin, TX'),
#  ('Oklahoma City, OK', 'Colorado Springs, CO'),
#  ('Oklahoma City, OK', 'Fort Worth, TX'),
#  ('Atlanta, GA', 'New Orleans, LA'),
#  ('Atlanta, GA', 'Charlotte, NC'),
#  ('Atlanta, GA', 'Memphis, TN'),
#  ('Atlanta, GA', 'Indianapolis, IN'),
#  ('Atlanta, GA', 'Nashville-Davidson, TN'),
#  ('Atlanta, GA', 'Columbus, OH'),
#  ('Atlanta, GA', 'Jacksonville, FL'),
#  ('New Orleans, LA', 'Houston, TX'),
#  ('New Orleans, LA', 'Memphis, TN'),
#  ('New Orleans, LA', 'Austin, TX'),
#  ('New Orleans, LA', 'Fort Worth, TX'),
#  ('New Orleans, LA', 'Nashville-Davidson, TN'),
#  ('Miami, FL', 'Jacksonville, FL'),
#  ('Fresno, CA', 'San Diego, CA'),
#  ('Fresno, CA', 'Phoenix, AZ'),
#  ('Fresno, CA', 'San Francisco, CA'),
#  ('Fresno, CA', 'Los Angeles, CA'),
#  ('Fresno, CA', 'Las Vegas, NV'),
#  ('Philadelphia, PA', 'Boston, MA'),
#  ('Philadelphia, PA', 'Charlotte, NC'),
#  ('Philadelphia, PA', 'Washington D.C.'),
#  ('Philadelphia, PA', 'New York, NY'),
#  ('Philadelphia, PA', 'Detroit, MI'),
#  ('Philadelphia, PA', 'Columbus, OH'),
#  ('Philadelphia, PA', 'Virginia Beach, VA'),
#  ('Houston, TX', 'San Antonio, TX'),
#  ('Houston, TX', 'Memphis, TN'),
#  ('Houston, TX', 'Tulsa, OK'),
#  ('Houston, TX', 'Austin, TX'),
#  ('Houston, TX', 'Fort Worth, TX'),
#  ('Boston, MA', 'Washington D.C.'),
#  ('Boston, MA', 'New York, NY'),
#  ('Boston, MA', 'Virginia Beach, VA'),
#  ('Kansas City, MO', 'Chicago, IL'),
#  ('Kansas City, MO', 'Memphis, TN'),
#  ('Kansas City, MO', 'Omaha, NE'),
#  ('Kansas City, MO', 'Tulsa, OK'),
#  ('Kansas City, MO', 'Minneapolis, MN'),
#  ('Kansas City, MO', 'Fort Worth, TX'),
#  ('Kansas City, MO', 'Indianapolis, IN'),
#  ('Kansas City, MO', 'Nashville-Davidson, TN'),
#  ('Kansas City, MO', 'Milwaukee, WI'),
#  ('San Diego, CA', 'Phoenix, AZ'),
#  ('San Diego, CA', 'San Francisco, CA'),
#  ('San Diego, CA', 'Los Angeles, CA'),
#  ('San Diego, CA', 'Las Vegas, NV'),
#  ('Chicago, IL', 'Memphis, TN'),
#  ('Chicago, IL', 'Omaha, NE'),
#  ('Chicago, IL', 'Minneapolis, MN'),
#  ('Chicago, IL', 'Indianapolis, IN'),
#  ('Chicago, IL', 'Detroit, MI'),
#  ('Chicago, IL', 'Nashville-Davidson, TN'),
#  ('Chicago, IL', 'Milwaukee, WI'),
#  ('Chicago, IL', 'Columbus, OH'),
#  ('Charlotte, NC', 'Washington D.C.'),
#  ('Charlotte, NC', 'Indianapolis, IN'),
#  ('Charlotte, NC', 'Nashville-Davidson, TN'),
#  ('Charlotte, NC', 'Columbus, OH'),
#  ('Charlotte, NC', 'Virginia Beach, VA'),
#  ('Charlotte, NC', 'Jacksonville, FL'),
#  ('Washington D.C.', 'New York, NY'),
#  ('Washington D.C.', 'Indianapolis, IN'),
#  ('Washington D.C.', 'Detroit, MI'),
#  ('Washington D.C.', 'Columbus, OH'),
#  ('Washington D.C.', 'Virginia Beach, VA'),
#  ('San Antonio, TX', 'Tulsa, OK'),
#  ('San Antonio, TX', 'Austin, TX'),
#  ('San Antonio, TX', 'Fort Worth, TX'),
#  ('Phoenix, AZ', 'Los Angeles, CA'),
#  ('Phoenix, AZ', 'Las Vegas, NV'),
#  ('San Francisco, CA', 'Los Angeles, CA'),
#  ('San Francisco, CA', 'Las Vegas, NV'),
#  ('Memphis, TN', 'Tulsa, OK'),
#  ('Memphis, TN', 'Fort Worth, TX'),
#  ('Memphis, TN', 'Indianapolis, IN'),
#  ('Memphis, TN', 'Nashville-Davidson, TN'),
#  ('Los Angeles, CA', 'Las Vegas, NV'),
#  ('New York, NY', 'Detroit, MI'),
#  ('New York, NY', 'Columbus, OH'),
#  ('New York, NY', 'Virginia Beach, VA'),
#  ('Denver, CO', 'Omaha, NE'),
#  ('Denver, CO', 'Colorado Springs, CO'),
#  ('Omaha, NE', 'Tulsa, OK'),
#  ('Omaha, NE', 'Minneapolis, MN'),
#  ('Omaha, NE', 'Colorado Springs, CO'),
#  ('Omaha, NE', 'Milwaukee, WI'),
#  ('Seattle, WA', 'Portland, OR'),
#  ('Tulsa, OK', 'Austin, TX'),
#  ('Tulsa, OK', 'Fort Worth, TX'),
#  ('Austin, TX', 'Fort Worth, TX'),
#  ('Minneapolis, MN', 'Milwaukee, WI'),
#  ('Indianapolis, IN', 'Detroit, MI'),
#  ('Indianapolis, IN', 'Nashville-Davidson, TN'),
#  ('Indianapolis, IN', 'Milwaukee, WI'),
#  ('Indianapolis, IN', 'Columbus, OH'),
#  ('Detroit, MI', 'Milwaukee, WI'),
#  ('Detroit, MI', 'Nashville-Davidson, TN'),
#  ('Detroit, MI', 'Columbus, OH'),
#  ('Nashville-Davidson, TN', 'Milwaukee, WI'),
#  ('Nashville-Davidson, TN', 'Columbus, OH'),
#  ('Milwaukee, WI', 'Columbus, OH'),
#  ('Columbus, OH', 'Virginia Beach, VA')]

# %%
# draw the graph using the default spring layout
plt.figure(figsize=(10,9))
nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# See what layouts are available in networkX
[x for x in nx.__dir__() if x.endswith('_layout')]
# Out:
# ['circular_layout',
#  'random_layout',
#  'shell_layout',
#  'spring_layout',
#  'spectral_layout',
#  'fruchterman_reingold_layout']

# %%
# Draw the graph using the random layout
plt.figure(figsize=(10,9))
pos = nx.random_layout(G)
nx.draw_networkx(G, pos)

# %%
# Draw the graph using the circular layout
plt.figure(figsize=(10,9))
pos = nx.circular_layout(G)
nx.draw_networkx(G, pos)

# %%
# Draw the graph using custom node positions
plt.figure(figsize=(10,7))

pos = nx.get_node_attributes(G, 'location')
nx.draw_networkx(G, pos)

# %%
# Draw the graph adding alpha, removing labels, and softening edge color
plt.figure(figsize=(10,7))

nx.draw_networkx(G, pos, alpha=0.7, with_labels=False, edge_color='.4')

plt.axis('off')
plt.tight_layout();

# %%
# Draw graph with varying node color, node size, and edge width
plt.figure(figsize=(10,7))

node_color = [G.degree(v) for v in G]
node_size = [0.0005*nx.get_node_attributes(G, 'population')[v] for v in G]
edge_width = [0.0015*G[u][v]['weight'] for u,v in G.edges()]

nx.draw_networkx(G, pos, node_size=node_size, 
                 node_color=node_color, alpha=0.7, with_labels=False, 
                 width=edge_width, edge_color='.4', cmap=plt.cm.Blues)

plt.axis('off')
plt.tight_layout();

# %%
# Draw specific edges and add labels to specific nodes
plt.figure(figsize=(10,7))

node_color = [G.degree(v) for v in G]
node_size = [0.0005*nx.get_node_attributes(G, 'population')[v] for v in G]
edge_width = [0.0015*G[u][v]['weight'] for u,v in G.edges()]

nx.draw_networkx(G, pos, node_size=node_size, 
                 node_color=node_color, alpha=0.7, with_labels=False, 
                 width=edge_width, edge_color='.4', cmap=plt.cm.Blues)


greater_than_770 = [x for x in G.edges(data=True) if x[2]['weight']>770]
nx.draw_networkx_edges(G, pos, edgelist=greater_than_770, edge_color='r', alpha=0.4, width=6)

nx.draw_networkx_labels(G, pos, labels={'Los Angeles, CA': 'LA', 'New York, NY': 'NYC'}, font_size=18, font_color='w')

plt.axis('off')
plt.tight_layout();
